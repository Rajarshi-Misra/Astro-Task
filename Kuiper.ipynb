# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from astropy.io import fits

# %%
KUIPERu=fits.open("frame-u-007907-5-0098.fits")
KUIPERi=fits.open("frame-i-007907-5-0098.fits")
KUIPERg=fits.open("frame-g-007907-5-0098.fits")

# %%
from astropy.visualization import make_lupton_rgb

# %%
g = KUIPERg[0].data
i = KUIPERi[0].data
u = KUIPERu[0].data

# %%
rgb_default = make_lupton_rgb(i, g, u, stretch=1.5, Q=10)
plt.imshow(rgb_default, origin='lower')
plt.savefig("rgbKUIPER.jpg")
